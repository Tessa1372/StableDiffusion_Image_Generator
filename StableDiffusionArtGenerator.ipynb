# %% [markdown]
# <a href="https://colab.research.google.com/github/Tessa1372/StableDiffusion_Image_Generator/blob/main/StableDiffusionArtGenerator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install huggingface_hub

# %%
from huggingface_hub import login
login()

# %%
from diffusers import StableDiffusionPipeline
import torch

# Load pre-trained model
model_id = "CompVis/stable-diffusion-v1-4"
pipe = StableDiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float16)
pipe.to("cuda")

# Set the prompt for the landscape
prompt = "A beautiful serene sunset over the mountains, soft lighting, vivid colors"

# Generate an image
image = pipe(prompt).images[0]

# Save the generated image
image.save("generated_landscape.png")
# Out:
# ...
#   0%|          | 0/50 [00:00<?, ?it/s]
